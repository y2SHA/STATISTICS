# %% [markdown]
# Q1. What is Statistics?
# -/ Numbers that have been collected in order to provide information about something
#
#
# Q2. Define the different types of statistics and give an example of when each type might be used.
#  -/ There are two types of statistics
#     1) Descriptive statistics
#     eg- histogram
#     2) Inferential statistics
#     eg- l-test, t-test
#
# Q3. What are the different types of data and how do they differ from each other? Provide an example of
# each type of data
# -/   There are two types of data
# 1)  QUANTITATIVE
#    a) discrete eg- whole no (number of bikes in family)
#    b) continious eg - anynumber( speed, temperature)
# 2) QUALITATIVE
#    a) nominal eg- gender , country,
#    b) ordinal eg - feedback good, best , better
#
#
# Q4. Categorise the following datasets with respect to quantitative and qualitative data types:
# (i) Grading in exam: A+, A, B+, B, C+, C, D, E             - QUANTITATIVE
# (ii) Colour of mangoes: yellow, green, orange, red         - QUALITATIVE
# (iii) Height data of a class: [178.9, 179, 179.5, 176, 177.2, 178.3, 175.8,...]   - QUANTITATIVE
# (iv) Number of mangoes exported by a farm: [500, 600, 478, 672, ...]              -  QUANTITATIVE
#
#
# Q5. Explain the concept of levels of measurement and give an example of a variable for each level.
#
# -/  It is a classification that describe the nature of information within the values assigned to variables
#
# Q6. Why is it important to understand the level of measurement when analyzing data? Provide an
# example to illustrate your answer.
#
# -/ The levelof measurement determines the type of statistical analysis that can be conducted and therefore the type of conclusion that can be drawn from the research.
#  has some prede
#
# Q7. How nominal data type is different from ordinal data type.
#
# -/ While Nominal Data is classified without any intrinsic ordering or rank, ordinal DAta has some predetermine or natural order
#
# Q8. Which type of plot can be used to display data in terms of range?
#
# -/ descriptive (histogram)
#
# Q9. Describe the difference between descriptive and inferential statistics. Give an example of each
# type of statistics and explain how they are used.
#
# -/ Descriptive Statistics is that branch which is concerned with describing the population under study.
#    Inferential statistics is a type of statistics that focus on drawing conclusion about the population,
#    on the basis of sample analysis and observation
#
# Q10. What are some common measures of central tendency and variability used in statistics? Explain
# how each measure can be used to describe a dataset.
#
# -/ MEAN , MODE , MEDIAN
